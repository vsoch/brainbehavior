# %%
# %matplotlib inline
import pandas

data = pandas.read_pickle("data/CNP_raw.pkl")

# %%
# For each variable, let's look at the data
for variable in data.columns:
# Out:
# ptid
# chapphy_testdate
# chapphy_initials
# chapphy1
# chapphy2
# chapphy3
# chapphy4
# chapphy5
# chapphy6
# chapphy7
# chapphy8
# chapphy9
# chapphy10
# chapphy11
# chapphy12
# chapphy13
# chapphy14
# chapphy15
# chapphy16
# chapphy17
# chapphy18
# chapphy19
# chapphy20
# chapphy21
# chapphy22
# chapphy23
# chapphy24
# chapphy25
# chapphy26
# chapphy27
# chapphy28
# chapphy29
# chapphy30
# chapphy31
# chapphy32
# chapphy33
# chapphy34
# chapphy35
# chapphy36
# chapphy37
# chapphy38
# chapphy39
# chapphy40
# chapphy41
# chapphy42
# chapphy43
# chapphy44
# chapphy45
# chapphy46
# chapphy47
# chapphy48
# chapphy49
# chapphy50
# chapphy51
# chapphy52
# chapphy53
# chapphy54
# chapphy55
# chapphy56
# chapphy57
# chapphy58
# chapphy59
# chapphy60
# chapphy61
# chapphy_total
# tci_testdate
# tci_initials
# tci8p
# tci60p
# tci94p
# tci114p
# tci134p
# tci189p
# tci197p
# tci200p
# tci240p
# tci5p
# tci22p
# tci45p
# tci111p
# tci140p
# tci163p
# tci173p
# tci228p
# tci37p
# tci62p
# ...
